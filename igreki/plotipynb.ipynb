# %%
import pandas as pd
import csv
import numpy as np
import matplotlib as mpl
from matplotlib import style 
from matplotlib import pyplot as plt

style.use('default')

y1,Eg_AlGaAs,alc_AlGaAs,so_AlGaAs,mhh_AlGaAs,mlh_AlGaAs,me_AlGaAs,VBO_AlGaAs = np.loadtxt('AlGaAs.csv', unpack=True, delimiter=',')
y2,Eg_AlAsSb,alc_AlAsSb,so_AlAsSb,mhh_AlAsSb,mlh_AlAsSb,me_AlAsSb,VBO_AlAsSb = np.loadtxt('AlAsSb.csv', unpack=True, delimiter=',')
y3,Eg_AlGaSb,alc_AlGaSb,so_AlGaSb,mhh_AlGaSb,mlh_AlGaSb,me_AlGaSb,VBO_AlGaSb = np.loadtxt('AlGaSb.csv', unpack=True, delimiter=',')
y4,Eg_GaAsSb,alc_GaAsSb,so_GaAsSb,mhh_GaAsSb,mlh_GaAsSb,me_GaAsSb,VBO_GaAsSb = np.loadtxt('GaAsSb.csv', unpack=True, delimiter=',')
y02,Eg_AlGaAsSb2,alc_AlGaAsSb2,so_AlGaAsSb2,mhh_AlGaAsSb2,mlh_AlGaAsSb2,me_AlGaAsSb2,VBO_AlGaAsSb2 = np.loadtxt('dane02.csv', unpack=True, delimiter=',')
y04,Eg_AlGaAsSb4,alc_AlGaAsSb4,so_AlGaAsSb4,mhh_AlGaAsSb4,mlh_AlGaAsSb4,me_AlGaAsSb4,VBO_AlGaAsSb4 = np.loadtxt('dane04.csv', unpack=True, delimiter=',')
y06,Eg_AlGaAsSb6,alc_AlGaAsSb6,so_AlGaAsSb6,mhh_AlGaAsSb6,mlh_AlGaAsSb6,me_AlGaAsSb6,VBO_AlGaAsSb6 = np.loadtxt('dane06.csv', unpack=True, delimiter=',')
y08,Eg_AlGaAsSb8,alc_AlGaAsSb8,so_AlGaAsSb8,mhh_AlGaAsSb8,mlh_AlGaAsSb8,me_AlGaAsSb8,VBO_AlGaAsSb8 = np.loadtxt('dane08.csv', unpack=True, delimiter=',')

# %%
plt.plot(alc_AlAsSb, Eg_AlAsSb)
plt.xlabel('Parametr sieci $a_{lc}$ (A)')
plt.ylabel('Energia (eV)')
plt.title('Wykres zależności energii od paramteru sieci a\n dla materiału trójskładnikowego AlAsSb')
# Out:
# Text(0.5, 1.0, 'Wykres zależności energii od paramteru sieci a\n dla materiału trójskładnikowego AlAsSb')

# %%
plt.plot(alc_GaAsSb, Eg_GaAsSb)
plt.xlabel('Parametr sieci $a_{lc}$ (A)')
plt.ylabel('Energia (eV)')
plt.title('Wykres zależności energii od paramteru sieci a dla materiału trójskładnikowego GaAsSb')
# Out:
# Text(0.5, 1.0, 'Wykres zależności energii od paramteru sieci a dla materiału trójskładnikowego GaAsSb')

# %%
plt.plot(y1, Eg_AlGaAsSb2, label='$Al_{0.2}$$Ga_{0.8}$$As_y$$Sb_{1-y}$')
plt.plot(y1, Eg_AlGaAsSb4, label='$Al_{0.4}$$Ga_{0.6}$$As_y$$Sb_{1-y}$')
plt.plot(y1, Eg_AlGaAsSb6, label='$Al_{0.6}$$Ga_{0.4}$$As_y$$Sb_{1-y}$')
plt.plot(y1, Eg_AlGaAsSb8, label='$Al_{0.8}$$Ga_{0.2}$$As_y$$Sb_{1-y}$')
plt.plot(y1, Eg_GaAsSb,label='Ga$As_y$$Sb_{1-y}$')
plt.plot(y1, Eg_AlAsSb,label='Al$As_y$$Sb_{1-y}$')
plt.xlabel('\nZawartość molowa w materiale')
plt.ylabel('\nEnergia (eV)')
plt.title('Wartość przerwy energetycznej\n w zaleznosci od domieszkowania materiału pierwistakmi grupy V\n')
plt.legend(loc = 'best', ncol=2, prop={"size":8})

# %%
plt.plot(y1, alc_AlGaAsSb2, label='$Al_{0.2}$$Ga_{0.8}$$As_y$$Sb_{1-y}$')
plt.plot(y1, alc_AlGaAsSb4, label='$Al_{0.4}$$Ga_{0.6}$$As_y$$Sb_{1-y}$')
plt.plot(y1, alc_AlGaAsSb6, label='$Al_{0.6}$$Ga_{0.4}$$As_y$$Sb_{1-y}$')
plt.plot(y1, alc_AlGaAsSb8, label='$Al_{0.8}$$Ga_{0.2}$$As_y$$Sb_{1-y}$')
plt.plot(y1, alc_GaAsSb,label='Ga$As_y$$Sb_{1-y}$')
plt.plot(y1, alc_AlAsSb,label='Al$As_y$$Sb_{1-y}$')
plt.xlabel('\nZawartość molowa w materiale')
plt.ylabel('\nParamter sieci $a_{lc}$')
plt.title('Wartość parametru sieci\n w zaleznosci od domieszkowania materiału pierwistakmi grupy V\n')
plt.legend(loc='best')

# %%
plt.plot(y1, so_AlGaAsSb2, label='$Al_{0.2}$$Ga_{0.8}$$As_y$$Sb_{1-y}$')
plt.plot(y1, so_AlGaAsSb4, label='$Al_{0.4}$$Ga_{0.6}$$As_y$$Sb_{1-y}$')
plt.plot(y1, so_AlGaAsSb6, label='$Al_{0.6}$$Ga_{0.4}$$As_y$$Sb_{1-y}$')
plt.plot(y1, so_AlGaAsSb8, label='$Al_{0.8}$$Ga_{0.2}$$As_y$$Sb_{1-y}$')
plt.plot(y1, so_GaAsSb,label='Ga$As_y$$Sb_{1-y}$')
plt.plot(y1, so_AlAsSb,label='Al$As_y$$Sb_{1-y}$')
plt.xlabel('\nZawartość molowa w materiale')
plt.ylabel('\nRozszczepienie spin-orbity (eV)')
plt.title('Rozszczepienie spin-orbity\n w zaleznosci od domieszkowania materiału pierwistakmi grupy V\n')
plt.legend(loc='best')

# %%
plt.plot(y1, VBO_AlGaAsSb2, label='$Al_{0.2}$$Ga_{0.8}$$As_y$$Sb_{1-y}$')
plt.plot(y1, VBO_AlGaAsSb4, label='$Al_{0.4}$$Ga_{0.6}$$As_y$$Sb_{1-y}$')
plt.plot(y1, VBO_AlGaAsSb6, label='$Al_{0.6}$$Ga_{0.4}$$As_y$$Sb_{1-y}$')
plt.plot(y1, VBO_AlGaAsSb8, label='$Al_{0.8}$$Ga_{0.2}$$As_y$$Sb_{1-y}$')
plt.plot(y1, VBO_GaAsSb,label='Ga$As_y$$Sb_{1-y}$')
plt.plot(y1, VBO_AlAsSb,label='Al$As_y$$Sb_{1-y}$')
plt.xlabel('\nZawartość molowa w materiale')
plt.ylabel('\nPrzemieszcienie wierzchołka pasma walencyjnego (eV)')
plt.title('Przemiszczenie wierzchołka pasma walencyjnego\n w zaleznosci od domieszkowania materiału pierwistakmi grupy V\n')
plt.legend(loc='best')

# %%
plt.plot(y1, me_AlGaAsSb2, label='$Al_{0.2}$$Ga_{0.8}$$As_y$$Sb_{1-y}$')
plt.plot(y1, me_AlGaAsSb4, label='$Al_{0.4}$$Ga_{0.6}$$As_y$$Sb_{1-y}$')
plt.plot(y1, me_AlGaAsSb6, label='$Al_{0.6}$$Ga_{0.4}$$As_y$$Sb_{1-y}$')
plt.plot(y1, me_AlGaAsSb8, label='$Al_{0.8}$$Ga_{0.2}$$As_y$$Sb_{1-y}$')
plt.plot(y1, me_GaAsSb,label='Ga$As_y$$Sb_{1-y}$')
plt.plot(y1, me_AlAsSb,label='Al$As_y$$Sb_{1-y}$')
plt.xlabel('\nZawartość molowa w materiale')
plt.ylabel('\nMasa efektywna elektronów')
plt.title('Zmiana masy efektywnej elektronów\n w zaleznosci od domieszkowania materiału pierwistakmi grupy V\n')
plt.legend(loc = 'best', ncol=2, prop={"size":6})

# %%
plt.plot(y1, mhh_AlGaAsSb2, label='$Al_{0.2}$$Ga_{0.8}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mhh_AlGaAsSb4, label='$Al_{0.4}$$Ga_{0.6}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mhh_AlGaAsSb6, label='$Al_{0.6}$$Ga_{0.4}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mhh_AlGaAsSb8, label='$Al_{0.8}$$Ga_{0.2}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mhh_GaAsSb,label='Ga$As_y$$Sb_{1-y}$')
plt.plot(y1, mhh_AlAsSb,label='Al$As_y$$Sb_{1-y}$')
plt.xlabel('\nZawartość molowa w materiale')
plt.ylabel('\nMasa ciężkich dziur')
plt.title('Zmiana masy ciężkich dziur\n w zaleznosci od domieszkowania materiału pierwistakmi grupy V\n')
plt.legend(loc = 'best', ncol=2, prop={"size":7})

# %%
plt.plot(y1, mlh_AlGaAsSb2, label='$Al_{0.2}$$Ga_{0.8}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mlh_AlGaAsSb4, label='$Al_{0.4}$$Ga_{0.6}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mlh_AlGaAsSb6, label='$Al_{0.6}$$Ga_{0.4}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mlh_AlGaAsSb8, label='$Al_{0.8}$$Ga_{0.2}$$As_y$$Sb_{1-y}$')
plt.plot(y1, mlh_GaAsSb,label='Ga$As_y$$Sb_{1-y}$')
plt.plot(y1, mlh_AlAsSb,label='Al$As_y$$Sb_{1-y}$')
plt.xlabel('\nZawartość molowa w materiale')
plt.ylabel('\nMasa lekkich dziur')
plt.title('Zależność masy lekkich dziur\n w zaleznosci od domieszkowania materiału pierwistakmi grupy V\n')
plt.legend(loc = 'best', ncol=2, prop={"size":7})
