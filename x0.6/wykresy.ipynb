# %%
import pandas as pd
import csv
import numpy as np
import matplotlib as mpl
from matplotlib import style 
from matplotlib import pyplot as plt

style.use('default')

T,exx0,ezz0,E_c0,E_v_hh0,E_v_lh0,E_v_sh0, = np.loadtxt('plik0.csv', unpack=True, delimiter=',')
T,exx2,ezz2,E_c2,E_v_hh2,E_v_lh2,E_v_sh2, = np.loadtxt('plik1.csv', unpack=True, delimiter=',')
T,exx4,ezz4,E_c4,E_v_hh4,E_v_lh4,E_v_sh4, = np.loadtxt('plik2.csv', unpack=True, delimiter=',')
T,exx6,ezz6,E_c6,E_v_hh6,E_v_lh6,E_v_sh6, = np.loadtxt('plik3.csv', unpack=True, delimiter=',')
T,exx8,ezz8,E_c8,E_v_hh8,E_v_lh8,E_v_sh8, = np.loadtxt('plik4.csv', unpack=True, delimiter=',')
T,exx10,ezz10,E_c10,E_v_hh10,E_v_lh10,E_v_sh10, = np.loadtxt('plik5.csv', unpack=True, delimiter=',')

# %%
plt.plot(T, E_c0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(T, E_c2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_c4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_c6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_c8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(T, E_c10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma przewodnictwa $E_{c}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(T, E_v_hh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(T, E_v_hh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_v_hh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_v_hh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_v_hh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(T, E_v_hh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma walencyjnego ciężkich dziur $E_{V,HH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(T, E_v_lh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(T, E_v_lh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_v_lh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_v_lh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_v_lh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(T, E_v_lh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma walencyjnego lekkich dziur $E_{V,LH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(T, E_v_sh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(T, E_v_sh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_v_sh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_v_sh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_v_sh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(T, E_v_sh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma walencyjnego $E_{v,SH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx0, E_c0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(exx2, E_c2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_c4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_c6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_c8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(exx10, E_c10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma przewodnictwa $E_{c}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx0, E_v_hh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(exx2, E_v_hh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_v_hh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_v_hh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_v_hh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(exx10, E_v_hh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma walencyjnego ciężkich dziur $E_{V,HH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx0, E_v_lh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(exx2, E_v_lh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_v_lh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_v_lh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_v_lh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(exx10, E_v_lh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma walencyjnego lekkich dziur $E_{V,LH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx0, E_v_hh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(exx2, E_v_sh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_v_sh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_v_sh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_v_sh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(exx10, E_v_sh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma walencyjnego $E_{v,SH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz2, E_c0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(ezz2, E_c2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_c4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_c6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_c8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(ezz10, E_c10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma przewodnictwa $E_{c}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz0, E_v_hh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(ezz2, E_v_hh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_v_hh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_v_hh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_v_hh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(ezz10, E_v_hh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma walencyjnego ciężkich dziur $E_{V,HH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz0, E_v_lh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(ezz2, E_v_lh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_v_lh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_v_lh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_v_lh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(ezz10, E_v_lh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma walencyjnego lekkich dziur $E_{V,LH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz0, E_v_sh0, label='$Al_{0.6}$$Ga_{0.4}$Sb')
plt.plot(ezz2, E_v_sh2, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_v_sh4, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_v_sh6, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_v_sh8, label='$Al_{0.6}$$Ga_{0.4}$$As_{0.8}$$Sb_{0.2}$')
plt.plot(ezz10, E_v_sh10, label='$Al_{0.6}$$Ga_{0.4}$As')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma walencyjnego $E_{V,SH}$ (eV)')
plt.legend(loc='best')
