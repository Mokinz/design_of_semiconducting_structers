# %%
import pandas as pd
import csv
import numpy as np
import matplotlib as mpl
from matplotlib import style 
from matplotlib import pyplot as plt

style.use('default')

T,exx2,ezz2,E_c2,E_v_hh2,E_v_lh2,E_v_sh2, = np.loadtxt('plik1.csv', unpack=True, delimiter=',')
T,exx4,ezz4,E_c4,E_v_hh4,E_v_lh4,E_v_sh4, = np.loadtxt('plik2.csv', unpack=True, delimiter=',')
T,exx6,ezz6,E_c6,E_v_hh6,E_v_lh6,E_v_sh6, = np.loadtxt('plik3.csv', unpack=True, delimiter=',')
T,exx8,ezz8,E_c8,E_v_hh8,E_v_lh8,E_v_sh8, = np.loadtxt('plik4.csv', unpack=True, delimiter=',')

# %%
plt.plot(T, E_c2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_c4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_c6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_c8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma przewodnictwa $E_{c}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(T, E_v_hh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_v_hh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_v_hh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_v_hh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma walencyjnego ciężkich dziur $E_{V,HH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(T, E_v_lh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_v_lh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_v_lh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_v_lh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma walencyjnego lekkich dziur $E_{V,LH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(T, E_v_sh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(T, E_v_sh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(T, E_v_sh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(T, E_v_sh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Temperatura (K)')
plt.ylabel('Wierzchołek pasma walencyjnego $E_{v,SH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx2, E_c2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_c4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_c6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_c8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma przewodnictwa $E_{c}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx2, E_v_hh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_v_hh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_v_hh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_v_hh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma walencyjnego ciężkich dziur $E_{V,HH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx2, E_v_lh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_v_lh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_v_lh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_v_lh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma walencyjnego lekkich dziur $E_{V,LH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(exx2, E_v_sh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(exx4, E_v_sh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(exx6, E_v_sh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(exx8, E_v_sh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi x')
plt.ylabel('Wierzchołek pasma walencyjnego $E_{v,SH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz2, E_c2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_c4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_c6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_c8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma przewodnictwa $E_{c}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz2, E_v_hh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_v_hh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_v_hh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_v_hh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma walencyjnego ciężkich dziur $E_{V,HH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz2, E_v_lh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_v_lh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_v_lh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_v_lh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma walencyjnego lekkich dziur $E_{V,LH}$ (eV)')
plt.legend(loc='best')

# %%
plt.plot(ezz2, E_v_sh2, label='Ga$As_{0.2}$$Sb_{0.8}$')
plt.plot(ezz4, E_v_sh4, label='Ga$As_{0.4}$$Sb_{0.6}$')
plt.plot(ezz6, E_v_sh6, label='Ga$As_{0.6}$$Sb_{0.4}$')
plt.plot(ezz8, E_v_sh8, label='Ga$As_{0.8}$$Sb_{0.2}$')
plt.xlabel('Odkształcenia wzdłuż osi z')
plt.ylabel('Wierzchołek pasma walencyjnego $E_{V,SH}$ (eV)')
plt.legend(loc='best')
